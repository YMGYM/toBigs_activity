# %% [markdown]
# # 5주차 차원축소 실습

# %% [markdown]
# ### Eigenvalue & Eigenvector 구하기 with numpy

# %%
import numpy as np
import numpy.linalg as lin
import matplotlib.pyplot as plt
import pandas as pd

np.random.seed(0)

testmatrix = np.array([[3,2],
                        [2,3]])

#Eigenvalue와 Eigenvector 함께 출력
print (lin.eig(testmatrix)) 

#Eigenvalue만 
print (lin.eig(testmatrix)[0])  

#Eigenvector만
print (lin.eig(testmatrix)[1])
# Out:
# (array([5., 1.]), array([[ 0.70710678, -0.70710678],
#        [ 0.70710678,  0.70710678]]))
# [5. 1.]
# [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
mat = lin.eig(testmatrix)[1] #eigenvector
print(mat[:,0]) #첫번째 eigenvector
print(mat[:,1]) #두번째 eigenvector
# Out:
# [0.70710678 0.70710678]
# [-0.70710678  0.70710678]

# %% [markdown]
# ### 스펙트럼분해 A=PΛP'
# 대칭행렬의 성질

# %%
# PP'=I인지 확인!
# e0'*e0 = 1 : 단위 벡터
print(mat[:,0].T.dot(mat[:,0]))
print(mat[:,1].T.dot(mat[:,1]))
# Out:
# 0.9999999999999999
# 0.9999999999999999

# %%
# 대칭행렬의 고유벡터들의 내적=0, 직교하는지 확인!!
# e0'*e1 = 0 고유벡터간의 직교
print(mat[:,0].T.dot(mat[:,1]))
# Out:
# 0.0

# %% [markdown]
# ### PCA 간단예제

# %%
# 랜덤값 생성
x = np.random.randn(100)
x2 = 0.5*x + np.random.randn(100)*0.3
X = pd.DataFrame({'x1':x,'x2':x2})

# %%
X
# Out:
#           x1        x2
# 0   1.764052  1.446971
# 1   0.400157 -0.204249
# 2   0.978738  0.108223
# 3   2.240893  1.411266
# 4   1.867558  0.581842
# ..       ...       ...
# 95  0.706573  0.301823
# 96  0.010500  0.236787
# 97  1.785870  1.139986
# 98  0.126912  0.712427
# 99  0.401989  0.601953
#
# [100 rows x 2 columns]

# %%
plt.scatter(X['x1'],X['x2'])

# %%
# 공분산행렬(데이터 구조를 설명)
mat = X.cov()
mat
# Out:
#           x1        x2
# x1  1.026087  0.548351
# x2  0.548351  0.389150

# %%
lin.eig(mat) #eigenvalue & eigenvaector
# Out:
# (array([1.34174117, 0.07349682]), array([[ 0.86666587, -0.49888903],
#         [ 0.49888903,  0.86666587]]))

# %%
e1 = lin.eig(mat)[1][:,0] #첫번째 고유벡터

# %%
e1
# Out:
# array([0.86666587, 0.49888903])

# %%
e2 = lin.eig(mat)[1][:,1] #두번째 고유벡터

# %%
e2
# Out:
# array([-0.49888903,  0.86666587])

# %% [markdown]
# ### 공분산행렬 스펙트럼 분해

# %%
plt.figure(figsize=(5,5))
plt.xlim(-3, 3) 
plt.ylim(-3, 3) 
plt.scatter(X['x1'],X['x2']);

# %%
plt.figure(figsize=(5,5))
plt.xlim(-3, 3) 
plt.ylim(-3, 3) 
plt.scatter(X['x1'],X['x2'])

# 고유벡터 시각화
plt.plot([-4*e1[0],4*e1[0]],[-4*e1[1],4*e1[1]],c='red')
plt.plot([-4*e2[0],4*e2[0]],[-4*e2[1],4*e2[1]],c='orange')

# %%
plt.figure(figsize=(5,5))
plt.xlim(-3, 3) 
plt.ylim(-3, 3) 

# 회전된 결과
PC1 = e1.dot(X.T)
# PC1 = e1[0]*X['x1'] + e1[1]*X['x2']
PC2 = e2.dot(X.T)
# PC2 = e2[0]*X['x1'] + e2[1]*X['x2']

plt.scatter(PC1,PC2);

plt.plot([0,0],[-3,3],c='orange');
plt.plot([-3,3],[0,0],c='red');

# %% [markdown]
# ### sklearn PCA

# %%
from sklearn.decomposition import PCA

# 2개로 축소 
model = PCA(n_components=2)

# fit : component 생성
# transform : 변환후 반환
# fit_transform : fit과 transform 동시 적용

pca_features = model.fit_transform(X)

# %%
#print(pca_features) #projection된 후의 데이터들 좌표

# %%
pca_features
# Out:
# array([[-2.17169516,  0.35657177],
#        [-0.16587799, -0.39405235],
#        [-0.82320336, -0.41189061],
#        [-2.56714364,  0.08773612],
#        [-1.82979639, -0.44484419],
#        [ 0.87888156,  0.552005  ],
#        [-0.9194716 , -0.1872275 ],
#        [ 0.35982741, -0.20181826],
#        [-0.09356982,  0.48932852],
#        [-0.60083007,  0.34061368],
#        [-0.36125297,  0.45871938],
#        [-1.67970753,  0.12283232],
#        [-0.64147834, -0.29121171],
#        [-0.34264893,  0.47123732],
#        [-0.37626222, -0.11618133],
#        [-0.41349143,  0.16936151],
#        [-1.7303023 ,  0.13093672],
#        [ 0.33120608, -0.04425578],
#        [-0.36229839,  0.12173442],
#        [ 0.89426845,  0.27836213],
#        [ 2.87210704,  0.24783203],
#        [-0.48593985, -0.3460952 ],
#        [-0.93041559,  0.00347022],
#        [ 0.70884923,  0.37611089],
#        [-2.35031607, -0.34678631],
#        [ 1.72465491,  0.03903502],
#        [ 0.0930834 , -0.13354214],
#        [ 0.01117158,  0.4756766 ],
#        [-1.73234399,  0.05691088],
#        [-1.6219231 , -0.00778802],
#        [ 0.02131933, -0.22773832],
#        [-0.42375181,  0.09801123],
#        [ 1.17081901, -0.13452913],
#        [ 2.2850505 ,  0.12072665],
#        [ 0.56250031, -0.15991464],
#        [-0.1967153 ,  0.14822029],
#        [-1.3804097 ,  0.05185784],
#        [-1.23178629, -0.15038353],
#        [ 0.45205742,  0.11095071],
#        [ 0.58002512, -0.28178051],
#        [ 1.47251943, -0.33639015],
#        [ 1.59816142,  0.18993   ],
#        [ 1.95846737,  0.13778891],
#        [-2.19329679,  0.01982022],
#        [ 0.29117761,  0.63562531],
#        [ 0.4266091 ,  0.25688031],
#        [ 1.61390397, -0.17260776],
#        [-0.95591826,  0.22205216],
#        [ 2.07726264, -0.25373734],
#        [ 0.38555244, -0.12346804],
#        [ 1.08867999,  0.02355792],
#        [-0.60922931,  0.40270231],
#        [ 0.76060688, -0.17755226],
#        [ 1.52043314, -0.15487875],
#        [ 0.1252165 , -0.04115269],
#        [-0.29973808, -0.21798654],
#        [-0.1638335 ,  0.27116189],
#        [-0.09693527, -0.31801338],
#        [ 0.9587383 , -0.27416047],
#        [ 0.54941323, -0.10745578],
#        [ 0.90410593, -0.10280701],
#        [ 0.19154126,  0.5078462 ],
#        [ 0.84449128,  0.28275331],
#        [ 1.9926454 ,  0.11852908],
#        [ 0.0644067 , -0.34764688],
#        [ 0.40108581,  0.22847079],
#        [ 2.04820721, -0.17058888],
#        [-0.20628832, -0.44938089],
#        [ 0.91386358,  0.35096383],
#        [-0.02638559,  0.06159709],
#        [-0.8725405 ,  0.17422417],
#        [-0.11263513,  0.05701092],
#        [-1.320909  ,  0.13067852],
#        [ 1.55466574, -0.10571871],
#        [-0.215239  , -0.31268141],
#        [ 0.74133861,  0.20470532],
#        [ 1.17117638, -0.16920283],
#        [ 0.82828973, -0.15873822],
#        [ 0.49493203, -0.11541675],
#        [ 0.01372419, -0.01653998],
#        [ 1.4324439 , -0.03305823],
#        [-0.7206104 , -0.43394425],
#        [-0.34437548, -0.21527022],
#        [ 2.12641393, -0.49477672],
#        [-1.67560311,  0.04759345],
#        [-1.79721995, -0.55822428],
#        [-1.07133174, -0.38181817],
#        [ 0.27203556,  0.00795551],
#        [ 1.38479304, -0.13949441],
#        [-1.32879549,  0.31465511],
#        [ 0.72251458, -0.32711435],
#        [-1.32532531, -0.02810814],
#        [-0.14755158, -0.04126979],
#        [-0.8361853 , -0.38513125],
#        [-0.39703438,  0.09528724],
#        [-0.68391192, -0.10832476],
#        [-0.04820358,  0.18257445],
#        [-2.03745281,  0.07963361],
#        [-0.38638535,  0.5367184 ],
#        [-0.56967129,  0.30374152]])

# %%
plt.figure(figsize=(5,5))
plt.xlim(-3, 3) 
plt.ylim(-3, 3) 

PC1 = pca_features[:,0] 
PC2 = pca_features[:,1] 

plt.scatter(PC1,PC2)

plt.plot([0,0],[-3,3],c='orange');
plt.plot([-3,3],[0,0],c='red');

# %%
plt.figure(figsize=(5,5))
plt.xlim(-3, 3) 
plt.ylim(-3, 3) 

# 1개의 주성분만 표현
plt.scatter(PC1,len(PC1)*[0]);

# %% [markdown]
# # IRIS DATA

# %%
from sklearn import datasets
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# 데이터 로드
iris = datasets.load_iris()

# %%
labels = np.array(iris.target)
data = pd.DataFrame(iris.data,columns=['Sepal length','Sepal width','Petal length','Petal width'])

# %%
data.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# 3차원
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
ax.scatter(data['Sepal length'],data['Sepal width'],data['Petal length'],c=labels,alpha=0.5, label=labels)
ax.set_xlabel('Sepal length')
ax.set_ylabel('Sepal width')
ax.set_zlabel('Petal length')
plt.show()

# %%
# 2차원
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.scatter(data['Sepal length'],data['Sepal width'],c=labels);
plt.show()

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt

# 정규화
scaler = StandardScaler()

# pca , 디폴트 components는 n(전체 feature 수)
pca = PCA()

# pipeline
pipeline = make_pipeline(scaler,pca)

# Fit the pipeline to 'samples'
# pipeline의 fit = 내장 전처리함수의 fit_transform 호출
pipeline.fit(data)

features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)  #pca.explained_variance_ : eigenvalue
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()

# %%
# 2차원
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

model = PCA(n_components=2)
pca_features = model.fit_transform(data)

pc1 = pca_features[:,0]
pc2 = pca_features[:,1]
plt.scatter(pc1,pc2,c=labels);
plt.show();

# %%
# 1차원
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

model = PCA(n_components=1)
pca_features = model.fit_transform(data)

pc1 = pca_features[:,0]
pc2 = len(pc1)*[0]
plt.scatter(pc1,pc2,c=labels);
plt.show();

# %% [markdown]
# ### LDA

# %%
# 2차원
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import matplotlib.pyplot as plt

model = LinearDiscriminantAnalysis(n_components=2)
lda_features = model.fit_transform(data, labels)

lc1 = lda_features[:,0]
lc2 = lda_features[:,1]
plt.scatter(lc1,lc2,c=labels)
plt.show();

# %%
# 1차원
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import matplotlib.pyplot as plt

model = LinearDiscriminantAnalysis(n_components=1)
lda_features = model.fit_transform(data, labels)

lc1 = lda_features[:,0]
lc2 = len(lc1)*[0]
plt.scatter(lc1,lc2,c=labels)
plt.show();

# %% [markdown]
# ### TSNE

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

model = TSNE(learning_rate=100.0) #10.0~1000.0
transformed = model.fit_transform(data)

tc1 = transformed[:,0]
tc2 = transformed[:,1]
plt.scatter(tc1,tc2,c=labels)

plt.show()
